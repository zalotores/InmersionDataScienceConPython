# %% [markdown]
# <h1>Clase 1 de Inmersion de datos</h1>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/drive/MyDrive/Alura/inmersionDataScience/clase1/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños': 'Banhos', 'Área': 'Area'}
inmuebles = inmuebles.rename(columns = columnas)
inmuebles.sample(10)
# Out:
#              Tipo                               Descripcion  Habitaciones  \
# 579   Apartamento          Apartamento en venta en El Batán             3
# 8522  Apartamento       Apartamento en venta en Teusaquillo             3
# 1541         Casa              Casa en venta en La Estancia             3
# 2333         Casa                     Casa en venta en Suba             3
# 4041         Casa                  Casa en venta en Kennedy             3
# 2358  Apartamento    Apartamento en venta en Barrios Unidos             2
# 6186  Apartamento        Apartamento en venta en La Calleja             3
# 5433  Apartamento              Apartamento en venta en Bosa             3
# 920   Apartamento  Apartamento en venta en Colina Campestre             3
# 8135  Apartamento          Apartamento en venta en El Tunal             2
#
#       Banhos  Area            Barrio  \
# 579        2   107          El Batán
# 8522       2    66       Teusaquillo
# 1541       2    65       La Estancia
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banhos        9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banhos                                        1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banhos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2       1
# 301  Apartamento  Apartamento en venta en Chico Norte             2       2
# 302  Apartamento      Apartamento en venta en Kennedy             3       2
# 303  Apartamento      Apartamento en venta en Kennedy             3       2
# 304  Apartamento     Apartamento en venta en Cedritos             4       4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles.iloc[301]
# Out:
# Tipo                                    Apartamento
# Descripcion     Apartamento en venta en Chico Norte
# Habitaciones                                      2
# Banhos                                            2
# Area                                             95
# Barrio                                  Chico Norte
# UPZ              CHAPINERO: Chicó Lago + El Refugio
# Valor                                 $ 980.000.000
# Name: 301, dtype: object

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 1046  Apartamento            Apartamento en venta en Engativa             2
# 3684  Apartamento            Apartamento en venta en Cedritos             2
# 1138  Apartamento       Apartamento en venta en San Cristobal             4
# 6036  Apartamento       Apartamento en venta en Santa Barbara             2
# 2773  Apartamento            Apartamento en venta en Cedritos             3
# 7542         Casa                    Casa en venta en Usaquén             4
# 7871  Apartamento                Apartamento en venta en Suba             7
# 5663  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 653   Apartamento            Apartamento en venta en Engativa             3
# 3836  Apartamento         Apartamento en venta en Bella Suiza             2
#
#       Banhos  Area              Barrio                                    UPZ  \
# ...

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
inmueblesChico = (inmuebles.Barrio == 'Chico Reservado')

# %%
chicoReservado = inmuebles[inmueblesChico]
chicoReservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banhos  Area           Barrio                                 UPZ  \
# ...

# %%
chicoReservado.Area.mean()
# Out:
# 142.78666666666666

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
inmueblesBarrio = inmuebles.Barrio.value_counts()
inmueblesBarrio.plot.bar()
# Out:
# <Axes: >

# %%
inmueblesBarrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# <h2>Ejercicios:</h2>

# %% [markdown]
# Promedio de Area de todos los barrios

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# Top ten de inmuebles con mayor area

# %%
topTenArea = inmuebles.Area.value_counts().head(10)
topTenArea
# Out:
# 47    260
# 60    174
# 48    172
# 54    168
# 70    151
# 50    143
# 51    142
# 59    133
# 53    133
# 63    132
# Name: Area, dtype: int64

# %% [markdown]
# Conteo de baños total

# %%
sumaBanhos = inmuebles.Banhos.sum()
sumaBanhos
# Out:
# 23304

# %% [markdown]
# Mediana

# %%
medianaBanhos = inmuebles.Banhos.median()
medianaBanhos
# Out:
# 2.0

# %% [markdown]
# Valores minimo y maximo

# %%
minBanhos = inmuebles.Banhos.min()
maxBanhos = inmuebles.Banhos.max()
minBanhos, maxBanhos
# Out:
# (0, 9)

# %% [markdown]
# <h1>Clase 2</h1>

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 8371  Apartamento           Apartamento en venta en Chapinero             3
# 1625  Apartamento                Apartamento en venta en Suba             3
# 684   Apartamento  Apartamento en venta en Zona Noroccidental             2
# 5681         Casa                Casa en venta en La Soledad              5
# 423          Casa                    Casa en venta en Boyaca              3
#
#       Banhos  Area              Barrio                                 UPZ  \
# 8371       2    88           Chapinero  CHAPINERO: Pardo Rubio + Chapinero
# 1625       2    80                Suba                                Suba
# 684        2    66  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 5681       2   210         La Soledad                          Teusaquillo
# 423        3   106             Boyaca                          Boyacá Real
#
#                 Valor
# 8371    $ 590.000.000
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banhos        9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 3511  Apartamento         Apartamento en venta en Usaquén             3
# 7405  Apartamento  Apartamento en venta en Barrios Unidos             2
# 5582  Apartamento       Apartamento en venta en Chapinero             3
#
#       Banhos  Area          Barrio                                 UPZ  \
# 3511       3   220         Usaquén                             Usaquén
# 7405       1    48  Barrios Unidos                           Los Andes
# 5582       5   342       Chapinero  CHAPINERO: Pardo Rubio + Chapinero
#
#                 Valor Moneda         Precio
# 3511  $ 1.540.000.000      $  1.540.000.000
# 7405    $ 309.000.000      $    309.000.000
# 5582  $ 3.500.000.000      $  3.500.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banhos        9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex=True)
inmuebles.sample(4)
# Out:
#              Tipo                      Descripcion  Habitaciones  Banhos  \
# 1347  Apartamento     Apartamento en venta en Bosa             3       1
# 8222         Casa         Casa en venta en Kennedy             9       4
# 1042  Apartamento     Apartamento en venta en Usme             2       1
# 4836  Apartamento  Apartamento en venta en Usaquén             4       6
#
#       Area   Barrio                                UPZ            Valor  \
# 1347    48     Bosa                       Bosa Central    $ 130.000.000
# 8222   250  Kennedy                    Kennedy Central    $ 480.000.000
# 1042    31     Usme  USME: Alfonso López + Ciudad Usme    $ 104.000.000
# 4836   307  Usaquén                            Usaquén  $ 1.500.000.000
#
#      Moneda      Precio
# 1347      $   130000000
# 8222      $   480000000
# 1042      $   104000000
# 4836      $  1500000000

# %%
inmuebles[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles['PrecioMillon'] = inmuebles.Precio.astype('float') / 1000000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banhos        9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
#  10  PrecioMillon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float.format', lambda x:'%.2f' %x)

# %%
inmuebles.describe()
# Out:
#        Habitaciones  Banhos      Area  PrecioMillon
# count       9520.00 9520.00   9520.00       9520.00
# mean           3.07    2.45    146.66        602.06
# std            2.05    1.26   1731.38        704.60
# min            1.00    0.00      2.00         60.00
# 25%            2.00    2.00     57.00        250.00
# 50%            3.00    2.00     80.00        409.18
# 75%            3.00    3.00    135.00        680.00
# max          110.00    9.00 166243.00      16000.00

# %%
inmuebles['PrecioMillon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
grafico = sns.histplot(data=inmuebles, x='PrecioMillon', kde=True, hue='Tipo')
grafico.set_title('Distribucion de valores de Inmuebles en Bogota')
plt.xlim((60,1000))
#plt.ylim((0,20))
plt.savefig('/content/drive/MyDrive/Alura/inmersionDataScience/clase1/distribValoresInmuebles.png', format='png')

plt.show()

# %% [markdown]
# <h3>Ejercicios:</h3>
#     Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información);
#
#     Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.
